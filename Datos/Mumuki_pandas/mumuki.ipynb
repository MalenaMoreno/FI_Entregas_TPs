# %%
import pandas as pd

# %%
cines = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=969960562&single=true&output=csv")
cines
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  \
# 0    10049030       10   10049  NaN  Salas de cine     Catamarca
# 1    10091150       10   10091  NaN  Salas de cine     Catamarca
# 2    22140060       22   22140  NaN  Salas de cine         Chaco
# 3    26091020       26   26091  NaN  Salas de cine        Chubut
# 4    18007010       18   18007  NaN  Salas de cine    Corrientes
# ..        ...      ...     ...  ...            ...           ...
# 324   6455030        6    6455  NaN  Salas de cine  Buenos Aires
# 325   6434010        6    6434  NaN  Salas de cine  Buenos Aires
# 326   6791050        6    6791  NaN  Salas de cine  Buenos Aires
# 327  10049030       10   10049  NaN  Salas de cine     Catamarca
# 328   6427010        6    6427  NaN  Salas de cine  Buenos Aires
#
#        department         city                            name  \
# 0         Capital    Catamarca                    Cinemacenter
# ...

# %%
type(cines)
# Out:
# pandas.core.frame.DataFrame

# %%
len(cines)
# Out:
# 329

# %%
list(cines.columns)
# Out:
# ['loc_code',
#  'prov_id',
#  'dep_id',
#  'obs',
#  'category',
#  'province',
#  'department',
#  'city',
#  'name',
#  'address',
#  'floor',
#  'zip_code',
#  'area_code',
#  'sector',
#  'screens',
#  'seats',
#  'update_year']

# %%
len(cines.columns)
# Out:
# 17

# %%
cines.head(5)
# Out:
#    loc_code  prov_id  dep_id  obs       category    province    department  \
# 0  10049030       10   10049  NaN  Salas de cine   Catamarca       Capital
# 1  10091150       10   10091  NaN  Salas de cine   Catamarca   Santa Maria
# 2  22140060       22   22140  NaN  Salas de cine       Chaco  San Fernando
# 3  26091020       26   26091  NaN  Salas de cine      Chubut     Sarmiento
# 4  18007010       18   18007  NaN  Salas de cine  Corrientes   Bella Vista
#
#           city                         name  \
# 0    Catamarca                 Cinemacenter
# 1  Santa María  Centro Cultural San Agustín
# 2  Resistencia        Los Cines De La Costa
# 3    Sarmiento    Deborah Jones De Williams
# 4  Bella Vista                     Fantasio
#
#                                  address floor  zip_code area_code  \
# 0          Intendente Mamerto Medina 220   s/d      4700       s/d
# 1                         San Martin 173   s/d      4139      3838
# ...

# %%
cines.head(2)
# Out:
#    loc_code  prov_id  dep_id  obs       category   province   department  \
# 0  10049030       10   10049  NaN  Salas de cine  Catamarca      Capital
# 1  10091150       10   10091  NaN  Salas de cine  Catamarca  Santa Maria
#
#           city                         name                        address  \
# 0    Catamarca                 Cinemacenter  Intendente Mamerto Medina 220
# 1  Santa María  Centro Cultural San Agustín                 San Martin 173
#
#   floor  zip_code area_code             sector  screens  seats  update_year
# 0   s/d      4700       s/d  Privado comercial        5    743         2018
# 1   s/d      4139      3838  Privado comercial        1    440         2018

# %%
cines.tail(3)
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  department  \
# 326   6791050        6    6791  NaN  Salas de cine  Buenos Aires      Tandil
# 327  10049030       10   10049  NaN  Salas de cine     Catamarca     Capital
# 328   6427010        6    6427  NaN  Salas de cine  Buenos Aires  La Matanza
#
#           city                            name         address floor  \
# 326     Tandil            Espacio INCAA Unicen    Yrigoyen 662   s/d
# 327  Catamarca           Cine Teatro Catamarca  San Martín 555   s/d
# 328  San Justo  Espacio INCAA Km 16 La Matanza  Av. Illia 2340   s/d
#
#      zip_code area_code                 sector  screens  seats  update_year
# 326      7000       249       Público nacional        1    430         2018
# 327      4700       383      Público municipal        1   1103         2018
# 328      1754        11  Privado independiente        1    390         2018

# %%
cines.tail(5)
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  department  \
# 324   6455030        6    6455  NaN  Salas de cine  Buenos Aires  Las Flores
# 325   6434010        6    6434  NaN  Salas de cine  Buenos Aires       Lanus
# 326   6791050        6    6791  NaN  Salas de cine  Buenos Aires      Tandil
# 327  10049030       10   10049  NaN  Salas de cine     Catamarca     Capital
# 328   6427010        6    6427  NaN  Salas de cine  Buenos Aires  La Matanza
#
#            city                            name         address floor  \
# 324  Las Flores                 Cine San Martin  San Martin 593   s/d
# 325       Lanús           Zona Cines Coto Lanús     Warnes 2450   s/d
# 326      Tandil            Espacio INCAA Unicen    Yrigoyen 662   s/d
# 327   Catamarca           Cine Teatro Catamarca  San Martín 555   s/d
# 328   San Justo  Espacio INCAA Km 16 La Matanza  Av. Illia 2340   s/d
#
#      zip_code area_code                 sector  screens  seats  update_year
# ...

# %%
cines.sort_values("city")
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  \
# 87    6826040        6    6826  NaN  Salas de cine  Buenos Aires
# 82    6588100        6    6588  NaN  Salas de cine  Buenos Aires
# 89    6028010        6    6028  NaN  Salas de cine  Buenos Aires
# 311   6028010        6    6028  NaN  Salas de cine  Buenos Aires
# 205  14140030       14   14140  NaN  Salas de cine       Córdoba
# ..        ...      ...     ...  ...            ...           ...
# 116  30113080       30   30113  NaN  Salas de cine    Entre Ríos
# 166  90119030       90   90119  NaN  Salas de cine       Tucumán
# 168  90119030       90   90119  NaN  Salas de cine       Tucumán
# 136  58112040       58   58112  NaN  Salas de cine       Neuquén
# 55    6882050        6    6882  NaN  Salas de cine  Buenos Aires
#
#           department          city                               name  \
# 87   Trenque Lauquen  30 De August     Cine Teatro Santa Rosa De Lima
# ...

# %%
cines.sort_values("city", ascending=False)
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  \
# 55    6882050        6    6882  NaN  Salas de cine  Buenos Aires
# 136  58112040       58   58112  NaN  Salas de cine       Neuquén
# 166  90119030       90   90119  NaN  Salas de cine       Tucumán
# 168  90119030       90   90119  NaN  Salas de cine       Tucumán
# 116  30113080       30   30113  NaN  Salas de cine    Entre Ríos
# ..        ...      ...     ...  ...            ...           ...
# 205  14140030       14   14140  NaN  Salas de cine       Córdoba
# 89    6028010        6    6028  NaN  Salas de cine  Buenos Aires
# 311   6028010        6    6028  NaN  Salas de cine  Buenos Aires
# 82    6588100        6    6588  NaN  Salas de cine  Buenos Aires
# 87    6826040        6    6826  NaN  Salas de cine  Buenos Aires
#
#           department          city                               name  \
# 55            Zarate        Zarate                Cine Teatro Coliseo
# ...

# %%
cines.sort_values("screens")
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  \
# 328   6427010        6    6427  NaN  Salas de cine  Buenos Aires
# 279   6112010        6    6112  NaN  Salas de cine  Buenos Aires
# 133  58035070       58   58035  NaN  Salas de cine       Neuquén
# 134  58035040       58   58035  NaN  Salas de cine       Neuquén
# 136  58112040       58   58112  NaN  Salas de cine       Neuquén
# ..        ...      ...     ...  ...            ...           ...
# 184  82084270       82   82084  NaN  Salas de cine      Santa Fe
# 304   6568010        6    6560  NaN  Salas de cine  Buenos Aires
# 59    6035010        6    6035  NaN  Salas de cine  Buenos Aires
# 318   6756010        6    6756  NaN  Salas de cine  Buenos Aires
# 305   6861010        6    6861  NaN  Salas de cine  Buenos Aires
#
#         department        city                                 name  \
# 328     La Matanza   San Justo       Espacio INCAA Km 16 La Matanza
# ...

# %%
cines.sort_values("screens", ascending=False)
# Out:
#      loc_code  prov_id  dep_id  obs       category      province  \
# 305   6861010        6    6861  NaN  Salas de cine  Buenos Aires
# 59    6035010        6    6035  NaN  Salas de cine  Buenos Aires
# 318   6756010        6    6756  NaN  Salas de cine  Buenos Aires
# 184  82084270       82   82084  NaN  Salas de cine      Santa Fe
# 304   6568010        6    6560  NaN  Salas de cine  Buenos Aires
# ..        ...      ...     ...  ...            ...           ...
# 73    6294050        6    6294  NaN  Salas de cine  Buenos Aires
# 194  50021010       50   50021  NaN  Salas de cine       Mendoza
# 72    6063010        6    6063  NaN  Salas de cine  Buenos Aires
# 71    6441030        6    6441  NaN  Salas de cine  Buenos Aires
# 328   6427010        6    6427  NaN  Salas de cine  Buenos Aires
#
#            department              city                            name  \
# 305     Vicente Lopez             Munro                        Showcase
# ...

# %%
import pandas as pd # si en una celda anterior ya cargaste pandas,  
                    # esta línea la podés omitir
librerias = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=1473087913&single=true&output=tsv", sep="\t")
librerias
# Out:
#        city_id  prov_id  dep_id  obs   category  \
# 0      2000010        2    2000  NaN  Librerias
# 1      2000010        2    2000  NaN  Librerias
# 2      2000010        2    2000  NaN  Librerias
# 3      2000010        2    2000  NaN  Librerias
# 4      2000010        2    2000  NaN  Librerias
# ...        ...      ...     ...  ...        ...
# 1618  90119030       90   90119  NaN  Librerias
# 1619  94007010       94   94007  NaN  Librerias
# 1620  94007010       94   94007  NaN  Librerias
# 1621  94014020       94   94014  NaN  Librerias
# 1622  94014020       94   94014  NaN  Librerias
#
#                                               prov_name  \
# 0                       Ciudad Autónoma de Buenos Aires
# 1                       Ciudad Autónoma de Buenos Aires
# 2                       Ciudad Autónoma de Buenos Aires
# 3                       Ciudad Autónoma de Buenos Aires
# 4                       Ciudad Autónoma de Buenos Aires
# ...

# %%
librerias["sector"].head(3)
# Out:
# 0    Privado
# 1    Privado
# 2    Privado
# Name: sector, dtype: object

# %%
librerias["city_name"].tail(4)
# Out:
# 1619    Río Grande
# 1620    Río Grande
# 1621       Ushuaia
# 1622       Ushuaia
# Name: city_name, dtype: object

# %%
len(librerias["city_name"])
# Out:
# 1623

# %%
len(librerias["city_name"].unique())
# Out:
# 254

# %%
pd.value_counts(librerias["prov_name"])
# Out:
# Ciudad Autónoma de Buenos Aires                          608
# Buenos Aires                                             386
# Córdoba                                                  163
# Santa Fe                                                 116
# Mendoza                                                   46
# Entre Ríos                                                32
# Chaco                                                     31
# Neuquén                                                   26
# Río Negro                                                 24
# Tucumán                                                   23
# Misiones                                                  23
# Salta                                                     21
# Chubut                                                    19
# Corrientes                                                17
# Santa Cruz                                                14
# ...

# %%
pd.value_counts(librerias["update_year"])
# Out:
# 2018    1604
# 2020      19
# Name: update_year, dtype: int64

# %%
museos = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=127345811&single=true&output=csv")
museos
# Out:
#       loc_code  prov_id  dep_id  obs                            category  \
# 0      6588100        6    6588  NaN  Espacios de Exhibición Patrimonial
# 1      6077010        6    6077  NaN  Espacios de Exhibición Patrimonial
# 2      6035010        6    6035  NaN  Espacios de Exhibición Patrimonial
# 3      6035010        6    6035  NaN  Espacios de Exhibición Patrimonial
# 4      6049020        6    6049  NaN  Espacios de Exhibición Patrimonial
# ...        ...      ...     ...  ...                                 ...
# 1177  90098040       90   90098  NaN  Espacios de Exhibición Patrimonial
# 1178  90105080       90   90105  NaN  Espacios de Exhibición Patrimonial
# 1179  90105080       90   90105  NaN  Espacios de Exhibición Patrimonial
# 1180  90105070       90   90105  NaN  Espacios de Exhibición Patrimonial
# 1181  90098040       90   90098  NaN  Espacios de Exhibición Patrimonial
#
#       subcat      province               city  \
# ...

# %%
len(museos)
# Out:
# 1182

# %%
museos["city"].nunique()
# Out:
# 518

# %%
pd.value_counts(museos["province"])
# Out:
# Santa Fe                                                 162
# Buenos Aires                                             152
# Ciudad Autónoma de Buenos Aires                          132
# Córdoba                                                  126
# Mendoza                                                   63
# Entre Ríos                                                57
# Jujuy                                                     47
# Chubut                                                    45
# La Pampa                                                  45
# Neuquén                                                   39
# Salta                                                     36
# Chaco                                                     33
# Catamarca                                                 32
# Misiones                                                  32
# San Luis                                                  31
# ...

# %%
pd.value_counts(museos["city"])
# Out:
# Ciudad Autónoma de Buenos Aires    132
# Santa Fe                            54
# Cordoba                             31
# La Plata                            24
# Mendoza                             20
#                                   ...
# Viale                                1
# Rosario del Tala                     1
# Nogoya                               1
# Libertador Norte                     1
# Villa El Cadillal                    1
# Name: city, Length: 518, dtype: int64

# %%
arboles = pd.read_csv("https://github.com/MumukiProject/datasets/raw/master/arbolado-publico-lineal.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/malemoreno/Documents/Fundamentos_de_Inf/FI_Entregas_TPs/Datos/mumuki.ipynb Celda 27 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/malemoreno/Documents/Fundamentos_de_Inf/FI_Entregas_TPs/Datos/mumuki.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> arboles = pd.read_csv("https://github.com/MumukiProject/datasets/raw/master/arbolado-publico-lineal.csv")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
arboles["height"].max()
# Out:
# 60.0

# %%
arboles["diameter"].mean()
# Out:
# 31.94135134990099

# %%
min(arboles["height"])
# Out:
# 0.0

# %%
min([2, 4, 8, 16, 32, 64, 128, 256, 512, 1024])
# Out:
# 2

# %%
sum(arboles["diameter"])
# Out:
# 11904350.0

# %%
sum([2, 4, 8, 16, 32, 64, 128, 256, 512, 1024])
# Out:
# 2046

# %%
# así se puede convertir una lista en un Series
unos_numeros = pd.Series([1, 1, 4, 8, 9, 1, 4, 8, 9, 8])
unos_numeros.mode()
# Out:
# 0    1
# 1    8
# dtype: int64

# %%
list(unos_numeros.mode())
# Out:
# [1, 8]

# %%
arboles["diameter"].median()
# Out:
# 28.0

# %%
arboles["diameter"].quantile(0.80)
# Out:
# 48.0

# %%
arboles["diameter"].quantile(0.75)
# Out:
# 43.0

# %%
arboles["height"].quantile(0.95)
# Out:
# 17.0

# %%
arboles["height"].max()
# Out:
# 60.0

# %%
arboles["height"].quantile(1)
# Out:
# 60.0

# %%
arboles["height"].min()
# Out:
# 0.0

# %%
arboles["height"].quantile(0)
# Out:
# 0.0

# %%
arboles["height"].quantile(0.5)
# Out:
# 8.0

# %%
arboles["height"].quantile(0.75)
# Out:
# 11.0

# %%
arboles["height"].median()
# Out:
# 8.0

# %%
arboles.describe()
# Out:
#                 long            lat       tree_id         height  \
# count  372659.000000  372659.000000  3.726940e+05  372694.000000
# mean      -58.458556     -34.613312  2.710744e+07       8.473085
# std         0.041818       0.034253  4.134081e+07       4.576827
# min       -58.530413     -34.702639  2.430000e+03       0.000000
# 25%       -58.491353     -34.639264  1.661592e+05       5.000000
# 50%       -58.465525     -34.615744  1.700314e+07       8.000000
# 75%       -58.428724     -34.586780  3.810204e+07      11.000000
# max       -58.342784     -34.534262  9.380002e+08      60.000000
#
#             diameter    inclination     species_id         comuna  \
# count  372694.000000  372686.000000  372694.000000  372694.000000
# mean       31.941351       3.069834      38.703695       9.124542
# std        20.207274       6.029981     141.187865       3.866489
# min         0.000000       0.000000       1.000000       1.000000
# ...

# %%
cruceros = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=751983160&single=true&output=csv")
cruceros
# Out:
#        cruise_id  country_id         country        date  date_id  port_id  \
# 0             41          57           Suiza  2016-12-02    13485        1
# 1             42          59  Otro de Europa  2016-12-02    13485        1
# 2             43          41          Canada  2016-12-02    13485        1
# 3             44          32        Colombia  2016-12-02    13485        1
# 4             45          70          EE.UU.  2016-12-02    13485        1
# ...          ...         ...             ...         ...      ...      ...
# 12011      11977          10       Argentina  2020-01-24    14633        2
# 12012      11978          10       Argentina  2020-01-24    14633        2
# 12013      11979          10       Argentina  2020-01-24    14633        2
# 12014      11980          10       Argentina  2020-01-24    14633        2
# 12015      11989          10       Argentina  2020-02-29    14669        2
#
# ...

# %%
cruceros["tours_expenses"].idxmin()
# Out:
# 0

# %%
cruceros["feed_expenses"].max()
# Out:
# 4000.0

# %%
cruceros["total_expenses"].mean()
# Out:
# 145.9711118508665

# %%
cruceros["total_expenses"].idxmax()
# Out:
# 384

# %%
cruceros["cruise_id"][384]
# Out:
# 796

# %%
cruceros["country"].mode()
# Out:
# 0    Brasil
# Name: country, dtype: object

# %% [markdown]
# **AGRUPACIONES Y GRAFICOS**

# %%
empleo = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=243182620&single=true&output=csv")
empleo
# Out:
#     year  employment_rate_female  employment_rate_male
# 0   2003                   45.80                 64.60
# 1   2004                   48.70                 66.60
# 2   2005                   50.50                 67.50
# 3   2006                   49.70                 68.90
# 4   2007                   50.70                 69.10
# 5   2008                   51.19                 68.56
# 6   2009                   51.37                 67.72
# 7   2010                   51.22                 67.62
# 8   2011                   50.56                 66.77
# 9   2012                   49.79                 66.80
# 10  2013                   49.47                 66.24
# 11  2014                   49.90                 65.90
# 12  2015                   52.10                 69.00
# 13  2016                   52.30                 67.40
# 14  2017                   52.20                 66.40
# 15  2018                   52.60                 65.70
# ...

# %%
empleo.plot.line(x="year")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
empleo.plot.line(x="year", y = ["employment_rate_female", "employment_rate_male"])
# Out:
# <AxesSubplot:xlabel='year'>

# %%
empleo.plot.bar(x="year", y = ["employment_rate_female", "employment_rate_male"])
# Out:
# <AxesSubplot:xlabel='year'>

# %%
empleo_total = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=1194930839&single=true&output=csv")
empleo_total.head(5)
# Out:
#    year  employment_rate
# 0  2003             54.3
# 1  2004             56.7
# 2  2005             58.3
# 3  2006             58.4
# 4  2007             59.1

# %%
empleo_total.plot.line(x="year", y="employment_rate")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
cines = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=969960562&single=true&output=csv")
cines.head(5)
# Out:
#    loc_code  prov_id  dep_id  obs       category    province    department  \
# 0  10049030       10   10049  NaN  Salas de cine   Catamarca       Capital
# 1  10091150       10   10091  NaN  Salas de cine   Catamarca   Santa Maria
# 2  22140060       22   22140  NaN  Salas de cine       Chaco  San Fernando
# 3  26091020       26   26091  NaN  Salas de cine      Chubut     Sarmiento
# 4  18007010       18   18007  NaN  Salas de cine  Corrientes   Bella Vista
#
#           city                         name  \
# 0    Catamarca                 Cinemacenter
# 1  Santa María  Centro Cultural San Agustín
# 2  Resistencia        Los Cines De La Costa
# 3    Sarmiento    Deborah Jones De Williams
# 4  Bella Vista                     Fantasio
#
#                                  address floor  zip_code area_code  \
# 0          Intendente Mamerto Medina 220   s/d      4700       s/d
# 1                         San Martin 173   s/d      4139      3838
# ...

# %%
cines = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=969960562&single=true&output=csv")
cines.head(5)
# Out:
#    loc_code  prov_id  dep_id  obs       category    province    department  \
# 0  10049030       10   10049  NaN  Salas de cine   Catamarca       Capital
# 1  10091150       10   10091  NaN  Salas de cine   Catamarca   Santa Maria
# 2  22140060       22   22140  NaN  Salas de cine       Chaco  San Fernando
# 3  26091020       26   26091  NaN  Salas de cine      Chubut     Sarmiento
# 4  18007010       18   18007  NaN  Salas de cine  Corrientes   Bella Vista
#
#           city                         name  \
# 0    Catamarca                 Cinemacenter
# 1  Santa María  Centro Cultural San Agustín
# 2  Resistencia        Los Cines De La Costa
# 3    Sarmiento    Deborah Jones De Williams
# 4  Bella Vista                     Fantasio
#
#                                  address floor  zip_code area_code  \
# 0          Intendente Mamerto Medina 220   s/d      4700       s/d
# 1                         San Martin 173   s/d      4139      3838
# ...
